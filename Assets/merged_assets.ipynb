# %%
import numpy as np
import pandas as pd

# %%
df_2008 = pd.read_stata('ca08a_1.0p_EN/ca08a_1.0p_EN.dta')
df_2008.head()
# Out:
#    nomem_encr  nohouse_encr   ca08a_m ca08a001 ca08a002  \
# 0    800033.0      583404.0  200806.0       no       no
# 1    800042.0      500277.0  200806.0      yes      yes
# 2    800057.0      580532.0  200806.0      yes       no
# 3    800076.0      578048.0  200806.0      yes       no
# 4    800119.0      537783.0  200806.0      yes       no
#
#                    ca08a003 ca08a004 ca08a005 ca08a006 ca08a007  ...  \
# 0      living-at-home child      yes       no       no       no  ...
# 1           married partner      yes       no      yes       no  ...
# 2         unmarried partner      yes       no       no       no  ...
# 3  family member or boarder      yes       no       no       no  ...
# 4           married partner       no       no       no       no  ...
#
#         ca08a066       ca08a067       ca08a068 ca08a069  ca08a070  ca08a071  \
# 0  certainly not  certainly yes              3        3         3  06-06-08
# ...
