# %%
import numpy as np
import pandas as pd

# %%
hea_10 = pd.read_stata('ch10d_EN_1.0p.dta')
rel_10 = pd.read_stata('cr10c_EN_2.0p.dta')
soc_10 = pd.read_stata('cs10c_1p_EN.dta')
fam_10 = pd.read_stata('cf10c_EN_1.0p.dta')
wor_10 = pd.read_stata('cw10c_EN_1.0p.dta')
per_10 = pd.read_stata('cp10c_1.0p_EN.dta')
val_10 = pd.read_stata('cv10c_EN_1.0p.dta')
ass_10 = pd.read_stata('ca10b_EN_1.0p.dta')
inc_10 = pd.read_stata('ci10c_EN_1.0p.dta')
hou_10 = pd.read_stata('cd10c_EN_1.1p.dta')

# %%
all_10 = [ass_10, hou_10, fam_10, hea_10, inc_10, per_10, soc_10, val_10, wor_10]

merged_10 = all_10[0]

for all in all_10[1:]:
    merged_10 = pd.merge(merged_10, all, on='nomem_encr', how='inner')
# Out:
# /var/folders/sf/kd52hmj913198w2y6076lcw80000gn/T/ipykernel_25649/1470168863.py:6: FutureWarning: Passing 'suffixes' which cause duplicate columns {'nohouse_encr_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_10 = pd.merge(merged_10, all, on='nomem_encr', how='inner')
# /var/folders/sf/kd52hmj913198w2y6076lcw80000gn/T/ipykernel_25649/1470168863.py:6: FutureWarning: Passing 'suffixes' which cause duplicate columns {'nohouse_encr_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_10 = pd.merge(merged_10, all, on='nomem_encr', how='inner')
# /var/folders/sf/kd52hmj913198w2y6076lcw80000gn/T/ipykernel_25649/1470168863.py:6: FutureWarning: Passing 'suffixes' which cause duplicate columns {'nohouse_encr_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_10 = pd.merge(merged_10, all, on='nomem_encr', how='inner')

# %%
merged_10.head()
# Out:
#    nomem_encr  nohouse_encr_x   ca10b_m ca10b001 ca10b002            ca10b003  \
# 0    829547.0        569088.0  201006.0      yes       no     married partner
# 1    877117.0        573492.0  201006.0      yes      yes     married partner
# 2    806234.0        543774.0  201006.0      yes      yes     married partner
# 3    867700.0        532952.0  201006.0      yes       no     married partner
# 4    886712.0        529281.0  201006.0      yes      yes  head of household*
#
#   ca10b076 ca10b077 ca10b078 ca10b005  ...       cw10c496       cw10c497  \
# 0      NaN      NaN      yes      yes  ...  certainly not              4
# 1      NaN      NaN      yes       no  ...  certainly not  certainly yes
# 2      NaN      NaN      yes       no  ...  certainly not  certainly yes
# 3      NaN      NaN      yes       no  ...              4              3
# 4      NaN      NaN      yes       no  ...              2              3
#
# ...
