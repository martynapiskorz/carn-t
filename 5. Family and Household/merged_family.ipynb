# %%
import numpy as np
import pandas as pd

# %%
fam_08 = pd.read_stata('cf08a_2p_EN/cf08a_2p_EN.dta')
fam_10 = pd.read_stata('cf10c_EN_1.0p/cf10c_EN_1.0p.dta')
fam_12 = pd.read_stata('cf12e_EN_2.1p/cf12e_EN_2.1p.dta')
fam_14 = pd.read_stata('cf14g_EN_1.1p/cf14g_EN_1.1p.dta')
fam_16 = pd.read_stata('cf16i_EN_1.0p/cf16i_EN_1.0p.dta')
fam_18 = pd.read_stata('cf18k_EN_1.0p/cf18k_EN_1.0p.dta')
fam_20 = pd.read_stata('cf20m_EN_1.0p/cf20m_EN_1.0p.dta')
fam_22 = pd.read_stata('cf22o_EN_1.0p/cf22o_EN_1.0p.dta')

# %%
fam_all = [fam_08, fam_10, fam_12, fam_14, fam_16, fam_18, fam_20]

fam_merged = fam_all[0]

for fam in fam_all[1:]:
    fam_merged = pd.merge(fam_merged, fam, on='nomem_encr', how='inner')

# %%
fam_merged.head()
# Out:
#    nomem_encr  nohouse_encr_x   cf08a_m        cf08a001  cf08a002 cf08a003  \
# 0    800119.0        537783.0  200803.0  not applicable       NaN   female
# 1    800170.0        520571.0  200803.0             3.0    1999.0   female
# 2    800186.0        534976.0  200803.0  not applicable       NaN   female
# 3    800201.0        529760.0  200803.0  not applicable       NaN     male
# 4    800204.0        555221.0  200803.0  not applicable       NaN     male
#
#    cf08a004      cf08a005   cf08a006      cf08a007  ...           cf20m388  \
# 0      57.0        1908.0        NaN            no  ...  1 = certainly not
# 1      49.0        1926.0        NaN           yes  ...  1 = certainly not
# 2      68.0        1909.0        NaN            no  ...  1 = certainly not
# 3      34.0        1948.0        NaN           yes  ...                2.0
# 4      66.0  I don't know  1910-1920  I don't know  ...  1 = certainly not
#
# ...
