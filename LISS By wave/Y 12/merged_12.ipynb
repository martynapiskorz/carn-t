# %%
import numpy as np
import pandas as pd

# %%
hea_12 = pd.read_stata('ch12f_EN_1.0p.dta')
rel_12 = pd.read_stata('cr12e_1.0p_EN.dta')
soc_12 = pd.read_stata('cs12e_1.0p_EN.dta')
fam_12 = pd.read_stata('cf12e_EN_2.1p.dta')
wor_12 = pd.read_stata('cw12e_EN_1.0p.dta')
per_12 = pd.read_stata('cp12e_1.0p_EN.dta')
val_12 = pd.read_stata('cv12e_EN_1.0p.dta')
ass_12 = pd.read_stata('ca12c_EN_1.0p.dta')
inc_12 = pd.read_stata('ci12e_1.0p_EN.dta')
hou_12 = pd.read_stata('cd12e_EN_1.0p.dta')

# %%
all_12 = [ass_12, hou_12, fam_12, hea_12, inc_12, per_12, soc_12, val_12, wor_12]

merged_12 = all_12[0]

for all in all_12[1:]:
    merged_12 = pd.merge(merged_12, all, on='nomem_encr', how='inner')

# %%
merged_12.head()
# Out:
#    nomem_encr   ca12c_m ca12c001 ca12c002            ca12c003  ca12c082  \
# 0    800170.0  201206.0      yes      yes  head of household*      53.0
# 1    800186.0  201206.0      yes       no     married partner      73.0
# 2    800198.0  201206.0      yes      yes  head of household*      55.0
# 3    800201.0  201206.0      yes      yes     married partner      38.0
# 4    800204.0  201206.0      yes       no  head of household*      70.0
#
#   ca12c078 ca12c005 ca12c006 ca12c007  ...           cw12e496  \
# 0      yes       no       no       no  ...                  3
# 1      yes       no       no       no  ...  1 = certainly not
# 2      yes       no       no      yes  ...  1 = certainly not
# 3      yes       no       no       no  ...  5 = certainly yes
# 4      yes       no       no       no  ...  1 = certainly not
#
#             cw12e497           cw12e498           cw12e499           cw12e500  \
# ...
